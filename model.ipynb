# %%
from model import Model

# %%
model = Model()
# Out:
# llama_init_from_model: n_ctx_per_seq (1024) < n_ctx_train (65536) -- the full capacity of the model will not be utilized

# %%
problem = """
В один из жарких летних дней Петя и его друг Вася решили купить арбуз. Они выбрали самый большой и самый спелый, на их взгляд. После недолгой процедуры взвешивания весы показали w килограмм. Поспешно прибежав домой, изнемогая от жажды, ребята начали делить приобретенную ягоду, однако перед ними встала нелегкая задача. Петя и Вася являются большими поклонниками четных чисел, поэтому хотят поделить арбуз так, чтобы доля каждого весила именно четное число килограмм, при этом не обязательно, чтобы доли были равными по величине. Ребята очень сильно устали и хотят скорее приступить к трапезе, поэтому Вы должны подсказать им, удастся ли поделить арбуз, учитывая их пожелание. Разумеется, каждому должен достаться кусок положительного веса.
Входные данные
В первой и единственной строке входных данных записано целое число w (1 ≤ w ≤ 100) — вес купленного ребятами арбуза.
Выходные данные
Выведите YES, если ребята смогут поделить арбуз на две части, каждая из которых весит четное число килограмм, и NO в противном случае.
"""

# %%
# code = model.create_solution(problem)
# print(code)

# %%
# print(model.create_tests(problem, code))

# %%
code = model.create_translated_solution(problem)
print(code)
# Out:
# In one of the warm summer days, Petya and his friend Vasya decided to buy a watermelon. They chose the largest and the most ripe one, according to their opinion. After a short weighing process, the scales showed w kilograms. Quickly running home, they were too tired to resist the thirst, so they decided to start eating the watermelon right away, but they were too tired to hurry to the trapeze. Therefore, you need to help them figure out if they can divide the watermelon into two parts, each weighing an even number of kilograms, and not necessarily of equal size. The children are very enthusiastic about even numbers, so they want to divide the watermelon so that each piece weighs exactly an even number of kilograms, and it is not necessary that the pieces are of the same size. The children are so tired that they want to get to the trapeze as soon as possible. Therefore, you need to help them figure out if they can divide the watermelon, taking into account their wish. Of course, each should receive a piece of positive weight.
#
# Input
# The first and only line of the input data contains an integer w (1 ≤ w ≤ 100) - the weight of the purchased watermelon.
#
# Output
# Print YES if the children can divide the watermelon into two parts, each weighing an even number of kilograms, and NO otherwise.
# w = int(input())
# if w % 2 == 0 and w != 2:
#     print('YES')
# else:
#     print('NO')

# %%
print(model.create_tests(problem, code))
